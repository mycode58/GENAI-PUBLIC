# %%
# TEXTBLOB
# pip install -U textblob
# python -m textblob.download_corpora

# %%
from textblob import TextBlob
from textblob import Word

# %%
example = TextBlob(" Telugu is a good language and also it is my mother tongue and i love TELUGU language")
example.words
# Out:
# WordList(['Telugu', 'is', 'a', 'good', 'language', 'and', 'also', 'it', 'is', 'my', 'mother', 'tongue', 'and', 'i', 'love', 'TELUGU', 'language'])

# %%
example.word_counts
# Out:
# defaultdict(int,
#             {'telugu': 2,
#              'is': 2,
#              'a': 1,
#              'good': 1,
#              'language': 2,
#              'and': 2,
#              'also': 1,
#              'it': 1,
#              'my': 1,
#              'mother': 1,
#              'tongue': 1,
#              'i': 1,
#              'love': 1})

# %%
w=TextBlob("I am learning my from Father about goodd things, and I ")
w.correct()
# Out:
# TextBlob("I am learning my from Father about good things, and I ")

# %%
w.words[-3].singularize()
# Out:
# 'thing'

# %%
x=TextBlob("I am learning my from Father about goodd thing, and I ")
x.words[-3].pluralize()
# Out:
# 'things'

# %%
text_india=TextBlob("India, officially the Republic of India, is a vast South Asian nation with a population exceeding 1.39 billion, making it one of the world's most populous countries. It is known for its immense cultural, linguistic, and geographical diversity, including the Himalayas, the Thar Desert, and over 7,500 kilometers of coastline. India's history features ancient civilizations like the Indus Valley, major empires, British colonial rule, and its 1947 independence.")

# %%
text_india.ngrams(3)
# Out:
# [WordList(['India', 'officially', 'the']),
#  WordList(['officially', 'the', 'Republic']),
#  WordList(['the', 'Republic', 'of']),
#  WordList(['Republic', 'of', 'India']),
#  WordList(['of', 'India', 'is']),
#  WordList(['India', 'is', 'a']),
#  WordList(['is', 'a', 'vast']),
#  WordList(['a', 'vast', 'South']),
#  WordList(['vast', 'South', 'Asian']),
#  WordList(['South', 'Asian', 'nation']),
#  WordList(['Asian', 'nation', 'with']),
#  WordList(['nation', 'with', 'a']),
#  WordList(['with', 'a', 'population']),
#  WordList(['a', 'population', 'exceeding']),
#  WordList(['population', 'exceeding', '1.39']),
#  WordList(['exceeding', '1.39', 'billion']),
#  WordList(['1.39', 'billion', 'making']),
#  WordList(['billion', 'making', 'it']),
#  WordList(['making', 'it', 'one']),
#  WordList(['it', 'one', 'of']),
#  WordList(['one', 'of', 'the']),
#  WordList(['of', 'the', 'world']),
#  WordList(['the', 'world', "'s"]),
#  WordList(['world', "'s", 'most']),
# ...

# %%
text_india.ngrams(2)
# Out:
# [WordList(['India', 'officially']),
#  WordList(['officially', 'the']),
#  WordList(['the', 'Republic']),
#  WordList(['Republic', 'of']),
#  WordList(['of', 'India']),
#  WordList(['India', 'is']),
#  WordList(['is', 'a']),
#  WordList(['a', 'vast']),
#  WordList(['vast', 'South']),
#  WordList(['South', 'Asian']),
#  WordList(['Asian', 'nation']),
#  WordList(['nation', 'with']),
#  WordList(['with', 'a']),
#  WordList(['a', 'population']),
#  WordList(['population', 'exceeding']),
#  WordList(['exceeding', '1.39']),
#  WordList(['1.39', 'billion']),
#  WordList(['billion', 'making']),
#  WordList(['making', 'it']),
#  WordList(['it', 'one']),
#  WordList(['one', 'of']),
#  WordList(['of', 'the']),
#  WordList(['the', 'world']),
#  WordList(['world', "'s"]),
#  WordList(["'s", 'most']),
#  WordList(['most', 'populous']),
#  WordList(['populous', 'countries']),
#  WordList(['countries', 'It']),
#  WordList(['It', 'is']),
#  WordList(['is', 'known']),
#  WordList(['known', 'for']),
# ...

# %%
text_india.ngrams(1)
# Out:
# [WordList(['India']),
#  WordList(['officially']),
#  WordList(['the']),
#  WordList(['Republic']),
#  WordList(['of']),
#  WordList(['India']),
#  WordList(['is']),
#  WordList(['a']),
#  WordList(['vast']),
#  WordList(['South']),
#  WordList(['Asian']),
#  WordList(['nation']),
#  WordList(['with']),
#  WordList(['a']),
#  WordList(['population']),
#  WordList(['exceeding']),
#  WordList(['1.39']),
#  WordList(['billion']),
#  WordList(['making']),
#  WordList(['it']),
#  WordList(['one']),
#  WordList(['of']),
#  WordList(['the']),
#  WordList(['world']),
#  WordList(["'s"]),
#  WordList(['most']),
#  WordList(['populous']),
#  WordList(['countries']),
#  WordList(['It']),
#  WordList(['is']),
#  WordList(['known']),
#  WordList(['for']),
#  WordList(['its']),
#  WordList(['immense']),
#  WordList(['cultural']),
#  WordList(['linguistic']),
#  WordList(['and']),
#  WordList(['geographical']),
#  WordList(['diversity']),
#  WordList(['including']),
#  WordList(['the']),
# ...

# %%
text_india.lower()
# Out:
# TextBlob("india, officially the republic of india, is a vast south asian nation with a population exceeding 1.39 billion, making it one of the world's most populous countries. it is known for its immense cultural, linguistic, and geographical diversity, including the himalayas, the thar desert, and over 7,500 kilometers of coastline. india's history features ancient civilizations like the indus valley, major empires, british colonial rule, and its 1947 independence.")

# %%
text_india.upper()
# Out:
# TextBlob("INDIA, OFFICIALLY THE REPUBLIC OF INDIA, IS A VAST SOUTH ASIAN NATION WITH A POPULATION EXCEEDING 1.39 BILLION, MAKING IT ONE OF THE WORLD'S MOST POPULOUS COUNTRIES. IT IS KNOWN FOR ITS IMMENSE CULTURAL, LINGUISTIC, AND GEOGRAPHICAL DIVERSITY, INCLUDING THE HIMALAYAS, THE THAR DESERT, AND OVER 7,500 KILOMETERS OF COASTLINE. INDIA'S HISTORY FEATURES ANCIENT CIVILIZATIONS LIKE THE INDUS VALLEY, MAJOR EMPIRES, BRITISH COLONIAL RULE, AND ITS 1947 INDEPENDENCE.")
